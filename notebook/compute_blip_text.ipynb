# %%
from PIL import Image

# %%
from transformers import AutoProcessor, Blip2ForConditionalGeneration
import torch

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", torch_dtype=torch.float16)
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/6.96k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/5.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
# Out:
# Blip2ForConditionalGeneration(
#   (vision_model): Blip2VisionModel(
#     (embeddings): Blip2VisionEmbeddings(
#       (patch_embedding): Conv2d(3, 1408, kernel_size=(14, 14), stride=(14, 14))
#     )
#     (encoder): Blip2Encoder(
#       (layers): ModuleList(
#         (0-38): 39 x Blip2EncoderLayer(
#           (self_attn): Blip2Attention(
#             (dropout): Dropout(p=0.0, inplace=False)
#             (qkv): Linear(in_features=1408, out_features=4224, bias=True)
#             (projection): Linear(in_features=1408, out_features=1408, bias=True)
#           )
#           (layer_norm1): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#           (mlp): Blip2MLP(
#             (activation_fn): GELUActivation()
#             (fc1): Linear(in_features=1408, out_features=6144, bias=True)
#             (fc2): Linear(in_features=6144, out_features=1408, bias=True)
#           )
#           (layer_norm2): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#   )
#   (qformer): Blip2QFormerModel(
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (encoder): Blip2QFormerEncoder(
#       (layer): ModuleList(
#         (0): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (language_projection): Linear(in_features=768, out_features=2560, bias=True)
#   (language_model): OPTForCausalLM(
#     (model): OPTModel(
#       (decoder): OPTDecoder(
#         (embed_tokens): Embedding(50272, 2560, padding_idx=1)
#         (embed_positions): OPTLearnedPositionalEmbedding(2050, 2560)
#         (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         (layers): ModuleList(
#           (0-31): 32 x OPTDecoderLayer(
#             (self_attn): OPTAttention(
#               (k_proj): Linear(in_features=2560, out_features=2560, bias=True)
#               (v_proj): Linear(in_features=2560, out_features=2560, bias=True)
#               (q_proj): Linear(in_features=2560, out_features=2560, bias=True)
#               (out_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             )
#             (activation_fn): ReLU()
#             (self_attn_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=2560, out_features=10240, bias=True)
#             (fc2): Linear(in_features=10240, out_features=2560, bias=True)
#             (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (lm_head): Linear(in_features=2560, out_features=50272, bias=False)
#   )
# )

# %%
import os
from tqdm.auto import tqdm
filenames = sorted(os.listdir("datasets/scale1_2/unsplash2000_raw"))

# %%
texts = {}
for filename in tqdm(filenames):
    image = Image.open(f"datasets/scale1_2/unsplash2000_raw/{filename}/image.png")
    inputs = processor(image, return_tensors="pt").to(device, torch.float16)
    generated_ids = model.generate(**inputs, max_new_tokens=20)
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
    texts[filename] = generated_text
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
texts
# Out:
# {'1.00000000': 'a black and white photo of people walking on the beach',
#  '1.00019737': 'a black and orange axe sitting on top of a stump',
#  '1.00021182': 'a plane flying through the clouds at sunset',
#  '1.00102300': 'the karlskrona tower in black and white',
#  '1.00173970': 'a mountain with a cloud cover over it',
#  '1.00187476': 'a man is kneeling down in front of a waterfall',
#  '1.00196995': 'a toy airplane on a desk',
#  '1.00291991': 'a dark ocean with waves and water',
#  '1.00324787': 'a waterfall in the background',
#  '1.00586515': 'a man standing on a snowy mountain top',
#  '1.00610399': 'a waterfall in the middle of a green valley',
#  '1.00630171': 'top view of palm trees in the jungle',
#  '1.00756587': 'flowers in the sun',
#  '1.00764210': 'a dark road with mountains in the background',
#  '1.00771052': 'a lone plant in the middle of a desert',
#  '1.00774183': 'the milky way over the ocean at night',
#  '1.00783084': 'an empty road in the middle of a forest',
#  '1.00835092': 'the glacier in iceland',
#  '1.00938884': 'a close up of a otter swimming in the water',
#  '1.00973734': 'black and white photograph of mountain range',
#  '1.01013875': 'a person sitting on the ground',
#  '1.01115230': 'a crab on the beach with its legs spread out',
#  '1.01214134': 'a close up of a hairy animal with a long horn',
#  '1.01214960': 'aerial view of a waterfall in the forest',
#  '1.01233617': 'a close up of a green leaf with many small spots',
#  '1.01243144': 'a red barn sits in the middle of a gravel field',
#  '1.01253397': 'woman in red jacket holding coffee mug on beach',
#  '1.01266905': 'frosted oak leaves',
#  '1.01354414': 'a boat is in the water',
#  '1.01401472': 'a sunflower in a field under a starry sky',
#  '1.01421400': 'a small cabin in the middle of a field',
#  '1.01443025': 'a mountain range with snow covered peaks',
#  '1.01477550': 'a man with a backpack standing on a rock in a lake',
#  '1.01486087': 'a large green valley',
#  '1.01498839': 'a cloudy sky',
#  '1.01626020': 'a group of seals resting on a dock',
#  '1.01715255': 'a person standing on a rock in the snow',
#  '1.01800902': 'a beach with green trees and blue water',
#  '1.01818345': 'a woman holding a vase of sunflowers',
#  '1.01825661': 'several cactus plants in pots on a table',
#  '1.01868708': 'a tiger laying down',
#  '1.01961544': 'a body of water',
#  '1.02029116': 'reindeer in the mountains',
#  '1.02044715': 'mountains in patagonia',
#  '1.02129777': 'a bald eagle with a fish in its talons',
#  '1.02140742': 'the building is curved and has a blue sky',
#  '1.02152764': 'a cloudy sky',
#  '1.02154227': 'a single sunflower in a field',
#  '1.02160605': 'a person sitting on the beach at sunset',
#  '1.02227632': 'a close up of some grass with the sun shining through',
#  '1.02255034': 'a deer is eating grass in a field',
#  '1.02265325': 'a lake with a foggy morning and a mountain in the background',
#  '1.02277847': 'a woman holding a bouquet of flowers in a mirror',
#  '1.02327270': 'a rock formation in the ocean at sunset',
#  '1.02349762': 'a view of a mountain range',
#  '1.02368864': 'the tv tower is lit up in blue and red',
#  '1.02380377': 'the view from the top of a cliff in iceland',
#  '1.02423903': 'a man standing in a field of yellow flowers',
#  '1.02474555': 'a bike is parked in a field',
#  '1.02487745': 'two elephants are in the water',
#  '1.02535522': "a close up of a giraffe's neck",
#  '1.02540086': 'a goat with a long white beard',
#  '1.02566804': 'a gray rabbit with large ears standing in the grass',
#  '1.02599524': 'penguins on the rocks near an iceberg',
#  '1.02607464': 'a field of sunflowers with many yellow flowers',
#  '1.02696824': 'a fish swimming over a coral reef',
#  '1.02707872': 'water flowing over rocks in a stream',
#  '1.02778342': 'aerial view of city street with traffic and buildings',
#  '1.02824102': 'aerial view of a valley and hills at sunset',
#  '1.02858317': 'a view of a greenhouse with plants and a window',
#  '1.02860806': 'a row of purple and blue flowers',
#  '1.02874255': 'a dog standing in front of a sunset',
#  '1.02882242': 'a couple walking on the beach near a mountain',
#  '1.02897567': 'joshua tree, joshua tree national park, california, usa',
#  '1.02999123': 'people walking down a city street in the sun',
#  '1.03064272': 'cherry blossoms in the city',
#  '1.03081395': 'a large sand dune',
#  '1.03082329': 'a plane flying over a foggy area',
#  '1.03115971': 'red and green leaves on a bush with red flowers',
#  '1.03120447': 'a small black bug is sitting on a moss covered rock',
#  '1.03144643': 'a sunset over the mountains with clouds',
#  '1.03180538': 'a blurry image of a sunset over water',
#  '1.03295374': 'a person jumping on a hill with a blue sky',
#  '1.03301959': 'three palm trees stand in front of a blue sky',
#  '1.03315236': 'sky is cloudy with dark clouds',
#  '1.03428923': 'a cave with rocks and dirt on the ground',
#  '1.03431908': 'a person is riding a snowboard down a slope',
#  '1.03434916': 'a man sitting on a rock overlooking a valley',
#  '1.03548990': 'a large glacier',
#  '1.03592987': 'a road in front of a mountain with snow on it',
#  '1.03621689': 'an aerial view of a small island in the ocean',
#  '1.03657678': 'a boat is sailing in the ocean near a small island',
#  '1.03743487': 'a white vase with pink flowers sitting on a table',
#  '1.03756108': 'a bright light shining in the sky above trees',
#  '1.03760071': 'a rose with water droplets on it',
#  '1.03932065': 'a valley with mountains and a river',
#  '1.03947844': 'a close up of some grass with a blurry background',
#  '1.03977558': 'black and white photo of trees in the snow',
#  '1.04021178': 'a boat is sailing in the ocean on a foggy day',
#  '1.04062929': 'a person standing on the rocks near the ocean',
#  '1.04072188': 'a boat is floating in the water',
#  '1.04084661': 'lavender field in the spring',
#  '1.04178543': 'a close up of tall grasses in the sun',
#  '1.04204415': 'sunset over the mountains',
#  '1.04260967': 'the mountains are very dry and have many different colors',
#  '1.04319920': 'a blurry photograph of pink flowers',
#  '1.04365317': 'a view of a valley with mountains in the background',
#  '1.04376748': 'black and white photo of mountains in fog',
#  '1.04430806': 'two chimneys stand on the beach at dusk',
#  '1.04439588': 'a body of water',
#  '1.04573591': 'a person holding a bird in front of a mountain range',
#  '1.04599029': 'a person standing on a ledge in a dark room',
#  '1.04606392': 'cactus plants against a red wall with the word no more',
#  '1.04665831': 'a person standing on top of a mountain overlooking the ocean',
#  '1.04705082': 'a large elk standing in a field surrounded by trees',
#  '1.04706142': 'an aerial view of a waterfall in the jungle',
#  '1.04752259': 'a red sky with clouds over the ocean',
#  '1.04765979': 'a sunset over the ocean with a rock arch',
#  '1.04772868': 'a woman walking on a pier at sunset',
#  '1.04776604': 'a cabin in the woods surrounded by snow',
#  '1.04853101': 'a forest with trees and fog in the background',
#  '1.04885436': 'a wooden fence',
#  '1.04900492': 'a close up of purple and white flowers',
#  '1.04901360': 'an aerial view of a beach with a row of houses',
#  '1.04919100': 'aerial view of london city at dusk',
#  '1.04973718': 'a white dog with a collar on a leash',
#  '1.05025190': 'a person standing on a glacier',
#  '1.05072585': 'a man is standing on a rock in the middle of a mountain',
#  '1.05141385': 'a large plane flying over the ocean at sunset',
#  '1.05143791': 'a mountain range is seen in the distance with snow on it',
#  '1.05144851': 'a close up of a succulent plant with blurry background',
#  '1.05171838': 'a river runs through a canyon at sunset',
#  '1.05177657': 'a pyramid of skulls in a dark room',
#  '1.05205424': 'a close up of a plant with green leaves',
#  '1.05295325': 'a squirrel is standing in the grass near a tree',
#  '1.05331331': 'the milky way galaxy is seen in this photo',
#  '1.05349372': 'a horse with a long mane standing in a field',
#  '1.05365454': 'a large archway with graffiti on it',
#  '1.05486171': 'a plane flying over a forest with fog',
#  '1.05504826': 'a man is standing on a hill with a cloud in the sky',
#  '1.05507452': 'a table with plants and a chair in front of a tropical garden',
#  '1.05574951': 'a small bouquet of pink flowers on a white background',
#  '1.05611546': 'water surface texture background',
#  '1.05665674': 'black and white photo of a stone circle in the middle of a field',
#  '1.05695854': 'close up of green pine needles',
#  '1.05833846': 'an aerial view of a snowy road and houses',
#  '1.05860961': 'the grand canyon at sunset',
#  '1.05890865': 'a field with trees and fog',
#  '1.05920897': 'a person flying a kite in the sky',
#  '1.06014650': 'an aerial view of a beach with waves',
#  '1.06034543': 'ice covered rocks in the water at the shore',
#  '1.06045653': 'a view of the mountains from a high place',
#  '1.06048202': 'a person on a snowboard is standing on a snowy hill',
#  '1.06112643': 'a gray fox standing in the snow',
#  '1.06170034': 'a man walking through a desert with a net',
#  '1.06299127': 'half dome at sunset',
#  '1.06325882': 'a snowy mountain with trees and skiers',
#  '1.06418531': 'a nest with four eggs in it',
#  '1.06428291': 'an elephant in black and white with tusks',
#  '1.06465614': 'poppies in a field',
#  '1.06474585': 'a large rock formation',
#  '1.06498468': 'man standing on top of a mountain overlooking the clouds',
#  '1.06534203': 'sunset over the mountains in the dolomites',
#  '1.06546540': "a person's hands are holding a book and a bowl of fruit",
#  '1.06564656': 'three pineapples on a white marble surface',
#  '1.06650740': 'a blue and yellow parrot sitting on a pole',
#  '1.06658353': 'a person riding a wave on a surfboard',
#  '1.06747317': 'a large mountain range',
#  '1.06867269': 'a white horse with a black bridle',
#  '1.06950254': 'a bird sitting on a railing',
#  '1.06960332': 'a man is sitting on a chair with a guitar',
#  '1.06968521': 'a man holding a plastic bag in front of trees',
#  '1.06974616': 'close up of a tree branch with brown berries',
#  '1.06999290': 'a woman in a polka dot top and skirt',
#  '1.07223601': 'ice cave in iceland',
#  '1.07233848': 'an aerial view of a river flowing through ice',
#  '1.07239951': 'a plane flying in the sky at sunset',
#  '1.07251574': 'a willow branch over the water at sunset',
#  '1.07331319': 'a view of hong kong from a mountain top',
#  '1.07373819': 'a group of flamingos',
#  '1.07470110': 'a wooden table with a basket on it',
#  '1.07499864': 'a tree on the side of the road',
#  '1.07501373': 'a house in a field of tall grass',
#  '1.07565919': 'a mountain range with trees and snow capped mountains',
#  '1.07598861': 'a dark ocean with a moon shining over it',
#  '1.07611360': 'aerial view of snow covered trees in the forest',
#  '1.07649417': 'wadi rum, jordan, desert, rocky, desert, jordan, desert, jordan',
#  '1.07753792': 'a woman with a rose on her head laying on the grass',
#  '1.07777985': 'a man is standing in front of a blue smoke cloud',
#  '1.07834476': 'a boat is in the water',
#  '1.07844150': 'the sky is blue',
#  '1.07860642': 'daisies in the grass',
#  '1.07882619': 'a bird sitting on a wooden bench',
#  '1.07895622': 'a flock of birds flying in the sky',
#  '1.07905797': 'a mountain range is silhouetted against a dark sky',
#  '1.07962762': 'a close up of a log with moss and wood',
#  '1.07965550': 'the milky way over the ocean at night',
#  '1.08001767': 'a pile of ice on a black surface',
#  '1.08034394': 'a stream runs through a lush forest',
#  '1.08089677': 'the grand canyon at sunset',
#  '1.08144564': 'mountains with trees and clouds in the background',
#  '1.08221939': 'a man standing on a hill with a snow covered mountain in the background',
#  '1.08308678': 'grand canyon national park, arizona',
#  '1.08321091': 'a tree with some branches and stars in the sky',
#  '1.08328035': 'a car driving over a bridge at sunset',
#  '1.08405417': 'the rock is red',
#  '1.08430315': 'the delicate arch in arches national park at sunset',
#  '1.08446010': 'a deer laying in the grass with its antlers',
#  '1.08462252': 'a beach with a pier and a boat in the water',
#  '1.08464041': 'a campfire is burning on the ground in the snow',
#  '1.08466427': 'a coyote stands in the snow near a stream',
#  '1.08480063': 'a foggy field with trees and grass',
#  '1.08540433': 'close up of leaves on a bush',
#  '1.08568138': 'a person sitting on a chair with a cat',
#  '1.08572731': 'a mountain range with snow capped peaks at night',
#  '1.08590222': 'a person standing on top of a mountain in the fog',
#  '1.08596119': 'a large rock formation',
#  '1.08632330': 'a view of the mountains from a ski lift',
#  '1.08638357': 'a close up of a sand covered beach',
#  '1.08694740': 'a person standing on a ledge overlooking the grand canyon',
#  '1.08727537': 'a dog running on the beach',
#  '1.08739416': 'a lone figure is standing on top of a large body of water',
#  '1.08817629': 'a hamster standing on its hind legs on a green blanket',
#  '1.08902447': 'a dark cloud is seen in the sky above a field',
#  '1.08905361': 'a close up of a bunch of blue flowers',
#  '1.08921258': 'a small cabin in the middle of a field',
#  '1.08929174': 'icebergs on the black sand beach in iceland',
#  '1.08947500': 'a young fox sitting in the grass',
#  '1.08950646': 'a person walking up a mountain at sunset',
#  '1.09060581': 'a horse in the ocean on a stormy day',
#  '1.09067676': 'a close up of green grass with water droplets',
#  '1.09083809': 'a field of grass with dew drops on it',
#  '1.09142513': 'a close up of a pine tree with blue needles',
#  '1.09165861': 'a large mountain',
#  '1.09236095': 'a large field of grass',
#  '1.09254745': 'a turtle swimming in the ocean with sunlight shining through the water',
#  '1.09293017': 'an abstract image of a sunset over water',
#  '1.09341141': 'the moon rises over the mountains in this photo',
#  '1.09401672': 'a red camera, polaroid pictures, and a blanket',
#  '1.09413729': 'the desert landscape in arches national park',
#  '1.09428217': 'a single rose is sitting on top of an old book',
#  '1.09440293': 'an open pit mine with mountains in the background',
#  '1.09441757': 'a tree trunk in the forest with a large tree trunk',
#  '1.09486864': 'a crescent moon is seen in the sky at sunset',
#  '1.09505423': 'an aerial view of a beach with waves and birds',
#  '1.09524929': 'the milky way is seen in the night sky',
#  '1.09601673': 'a mountain with flowers',
#  '1.09676984': 'a small glass bottle with dried flowers on a table',
#  '1.09698850': 'a man in a blue trunks sitting on a rock in the water',
#  '1.09752477': 'a person standing on a rock at sunset',
#  '1.09790305': 'a close up of a plant with a white background',
#  '1.09819566': 'a close up of a cat with big eyes',
#  '1.09848382': 'a mountain with the sun shining through the trees',
#  '1.09868792': 'black and white photo of a dog reaching up',
#  '1.09904543': 'a mountain with trees and fog in the background',
#  '1.09956304': 'a person jumping off a cliff into a river',
#  '1.09994927': 'a man standing on a hill overlooking a city',
#  '1.09999170': 'a close up of a plant with pink flowers',
#  '1.10012236': 'a view of the mountains from a plane',
#  '1.10065284': 'a mountain covered in snow and clouds',
#  '1.10070511': 'a mountain range with snow on the ground',
#  '1.10102556': 'a horse and a foal standing on a hill',
#  '1.10177489': 'a bird flying over the water',
#  '1.10240366': 'a dark stormy sky over a lake and mountains',
#  '1.10318225': 'a person walking on a path in the woods',
#  '1.10322674': 'a fox standing on a stump in a forest',
#  '1.10350867': 'a mountain with snow on it',
#  '1.10391704': 'pink flowers are shown in a large group',
#  '1.10408530': 'an aerial view of a city with snow on the ground',
#  '1.10479795': 'a red and white sign is sitting in the water',
#  '1.10496550': 'a painting of a blue and white abstract painting',
#  '1.10559901': 'a small boat floating in the ocean near a city',
#  '1.10605768': 'a mountain with trees and rocks on top',
#  '1.10622325': 'a lighthouse on a grassy field',
#  '1.10644816': 'a plant with green leaves sitting on a yellow wall',
#  '1.10711856': 'a group of palm trees',
#  '1.10740519': 'a mountain with a foggy sky and a cliff',
#  '1.10743485': 'an aerial view of a tropical island with a small lake',
#  '1.10770844': 'a vase with pink flowers in it',
#  '1.10798658': 'a horse eating grass in a field',
#  '1.10803921': 'black sand beach with waves and rocks',
#  '1.10827705': 'a herd of deer in a wooded area',
#  '1.10858702': 'black and white photo of foggy forest with trees',
#  '1.10908352': 'a white horse standing in a field of flowers',
#  '1.10937528': 'a person standing on top of a large red sand dune',
#  '1.10987598': 'a dog with a backpack sitting on a rock',
#  '1.11170046': 'a cityscape with buildings and trees',
#  '1.11259013': 'a display of pomegranates and oranges at a market',
#  '1.11325167': 'a group of islands in the ocean',
#  '1.11335797': "a close up of a bird's head with a black background",
#  '1.11358808': 'a person standing on top of a hill',
#  '1.11446032': 'a bear cub sitting in the grass',
#  '1.11463871': 'a close up of a christmas tree with snow on it',
#  '1.11472475': 'white flowers on a tree in front of a body of water',
#  '1.11554176': 'a person flying a kite in the desert',
#  '1.11558174': 'a person is walking on the beach at sunset',
#  '1.11565763': 'yosemite valley in winter with fog and trees',
#  '1.11584985': 'a cat laying on a couch',
#  '1.11619337': 'hands holding two wedding rings',
#  '1.11724138': 'flowers in a greenhouse',
#  '1.11752041': 'a wave on the beach',
#  '1.11753909': 'a sunset with clouds and trees in the background',
#  '1.11909559': 'a mountain range with trees and a river',
#  '1.11934099': 'a boat on a lake at sunset',
#  '1.11948805': 'yosemite falls, yosemite national park, california, usa',
#  '1.11955514': 'a mountain range',
#  '1.11970600': 'a mountain range with a road and trees',
#  '1.12058925': 'a path through a field of white flowers',
#  '1.12079555': 'a close up of water in the ocean',
#  '1.12101814': 'two trees are silhouetted against an orange sky',
#  '1.12120919': 'a mountain range with snow and clouds',
#  '1.12153604': 'a person riding a wave in the ocean',
#  '1.12256068': 'a black and white photo of a mountain range',
#  '1.12257119': 'a man and a woman sitting on a bench',
#  '1.12321972': 'a woman with a backpack walking her dog in the snow',
#  '1.12325715': 'a grasshopper is standing in the water',
#  '1.12411894': 'a close up of some white flowers',
#  '1.12450289': 'a man walking down a street with cows',
#  '1.12466299': 'colorful buildings on the coast of italy',
#  '1.12471669': 'a lake surrounded by mountains and trees',
#  '1.12495622': 'a monkey sitting on a log eating a piece of food',
#  '1.12509118': 'the lake in the middle of the mountains is reflecting the mountains',
#  '1.12644046': 'a small purple flower is growing on a plant',
#  '1.12673714': 'the moon rises over the red rocks of sedona, arizona',
#  '1.12682588': 'a lone tree in a field with a blue sky',
#  '1.12711528': 'a view up into a forest of tall trees',
#  '1.12733593': 'a man paddles a canoe on a calm lake with a mountain in the background',
#  '1.12744790': 'lightning strikes over the ocean in the dark',
#  '1.12833068': 'a large body of water',
#  '1.12842475': 'a man riding a snowboard down a snowy slope',
#  '1.12914832': 'man standing on top of mountain looking at valley',
#  '1.13078100': 'a black bird sitting on a rock',
#  '1.13120415': 'a person swimming underwater in the ocean',
#  '1.13176271': 'three cats sitting on a stone floor',
#  '1.13330966': 'a woman in a green bikini sitting on a towel near a pool',
#  '1.13376118': 'a silhouette of a person standing on top of a hill at sunset',
#  '1.13477162': 'water droplets are falling from a water fountain',
#  '1.13487410': 'a close up of sand with ripples in it',
#  '1.13586911': 'a beach with palm trees and a blue sky',
#  '1.13594083': "a close up of a flamingo's head",
#  '1.13613596': 'water surface with ripples and waves',
#  '1.13669915': 'a field of grass with water droplets on it',
#  '1.13713653': 'a couple on a canoe in a lake surrounded by trees',
#  '1.13716517': 'a person sitting on top of a mountain',
#  '1.13763509': 'a body of water',
#  '1.13782328': 'a dog is sitting on a couch',
#  '1.13794833': 'a mountain range with trees and mountains in the background',
#  '1.13809526': 'an aerial view of a walkway in the middle of a park',
#  '1.13811296': 'red poppy flowers in a field with blurry background',
#  '1.13857810': 'a view of a river flowing through a desert',
#  '1.13857890': 'a bird with a black head and red feet',
#  '1.13878218': 'a mountain covered in fog with trees on top',
#  '1.14034011': 'a frog sitting on top of a red flower',
#  '1.14034782': 'a sunset over the mountains with clouds and a dark sky',
#  '1.14058278': 'the view of paris from the top of the dome',
#  '1.14071878': 'an orange house on a pier in the ocean',
#  '1.14203414': 'a satellite image shows the green grass on the surface of the water',
#  '1.14216921': 'three horses standing in a field',
#  '1.14259037': 'a bird sitting on a branch',
#  '1.14305736': 'a mountain range is seen in the distance on a cloudy day',
#  '1.14419644': 'a man with a backpack walking through a forest',
#  '1.14429226': 'a woman wearing a pink coat',
#  '1.14442138': 'bali, indonesia, sunrise, rice terraces, mountains, sunrise, rice terraces',
#  '1.14452914': 'a bear walking in a field',
#  '1.14487308': 'a blue sky',
#  '1.14487445': 'a cloudy sky over a mountain range with a sun shining through',
#  '1.14514284': 'a church in the snow with mountains in the background',
#  '1.14609325': 'a leopard is resting on a fence',
#  '1.14681668': 'an aerial view of ice and water',
#  '1.14701694': 'a deer is standing in the grass',
#  '1.14710170': 'a snowy landscape with trees and a sky',
#  '1.14711652': 'a gorilla sitting on a rock with his arms crossed',
#  '1.14724534': 'a woman standing in front of a white tent',
#  '1.14748565': 'a black and white photo of a mountain range',
#  '1.14805378': 'a man stands in front of a rock formation at night',
#  '1.14847149': 'a close up of yellow leaves on the ground',
#  '1.14929452': 'a plane flying in the night sky with a green light',
#  '1.15044412': 'a view of the grand canyon from a cliff',
#  '1.15089235': 'red poppies in a field with green grass',
#  '1.15095033': 'a path in the woods with a green grassy area',
#  '1.15137662': 'a large mountain with snow on top',
#  '1.15144162': 'a mountain range',
#  '1.15176792': 'a row of deck chairs on the beach',
#  '1.15182449': 'a cactus plant with a bird perched on top',
#  '1.15238694': 'the stars are shining in the sky above trees',
#  '1.15285091': 'autumn leaves on a fallen tree',
#  '1.15346122': 'an aerial view of a boat in the ocean',
#  '1.15410368': 'a kitten with blue eyes sitting on a bed',
#  '1.15494692': 'a table with a vase of flowers, a teapot, and a bowl of fruit',
#  '1.15509168': 'a close up of a green plant with water droplets',
#  '1.15513831': 'a cat standing on a concrete step',
#  '1.15550242': 'a person standing on the beach at sunset',
#  '1.15613262': 'a person walking across a large sand dune',
#  '1.15665263': 'a man riding a horse in the desert',
#  '1.15790034': 'an island with a small arch in the middle of the ocean',
#  '1.15808614': 'a snow covered forest with trees and a snow covered road',
#  '1.15809846': 'the sun setting over the ocean with waves on the beach',
#  '1.15889722': 'a pine cone on a branch of a pine tree',
#  '1.16007091': 'a group of tents on the side of a road',
#  '1.16011699': 'coral reef with fish and coral in the red sea',
#  '1.16014684': 'a blue sky with clouds',
#  '1.16026272': 'a boston terrier dog standing on a blue stool',
#  '1.16061700': 'a bunch of flowers',
#  '1.16116659': 'mountains and flowers in the background',
#  '1.16139782': "a close up of a deer's face",
#  '1.16148101': 'a mountain with a moon in the sky',
#  '1.16231155': 'a snowy mountain range',
#  '1.16313659': 'a man sitting by a pool with palm trees',
#  '1.16319593': 'a palm tree against a blue sky',
#  '1.16321913': 'the sky is blue',
#  '1.16324423': 'two blue chairs sitting on the beach',
#  '1.16326713': 'a woman is bending over to look at her hair',
#  '1.16375765': 'a small plant in a metal pot on a pink background',
#  '1.16380829': 'the water is rough',
#  '1.16412992': 'a group of horses grazing on a hillside',
#  '1.16551536': 'cactus on yellow background',
#  '1.16584678': 'mount bromo, indonesia, indonesia, indonesia, indonesia',
#  '1.16586031': 'a snowy road in the mountains with trees',
#  '1.16625681': 'a lone tree in a foggy field',
#  '1.16635340': 'a view of the mountains from an airplane',
#  '1.16724748': 'a woman walking in the ocean',
#  '1.16735045': 'a path through a forest with trees and grass',
#  '1.16772675': 'flowers and signs are placed on the sidewalk near the white house',
#  '1.16798210': 'a fish with a white and orange body is swimming',
#  '1.16842664': 'a man standing on the shore of a lake with mountains in the background',
#  '1.16912379': 'a potted plant with green leaves on a table',
#  '1.16985572': 'a mountain with trees and rocks on top',
#  '1.17000464': 'the statue of liberty is seen in the sunset',
#  '1.17220372': 'three people standing in the desert with mountains in the background',
#  '1.17279707': 'a beach with a few umbrellas and a few people',
#  '1.17332083': 'a wedding staircase decorated with flowers and greenery',
#  '1.17464226': 'a jellyfish floating in the water',
#  '1.17498718': 'a pug wearing a yellow beanie hat',
#  '1.17501724': 'two elephants standing next to a pond',
#  '1.17504850': 'a mountain is lit up at dusk',
#  '1.17564980': 'a man is surfing on a large wave in the ocean',
#  '1.17632943': 'a mother giraffe and her baby are standing in a field',
#  '1.17669332': '4th of july dog photo shoot',
#  '1.17686425': 'a red light is on a pole in the ocean',
#  '1.17742356': 'a beach with a pink sunset',
#  '1.17806171': 'a view of the mountains',
#  '1.17813446': 'the sun is setting in the middle of a forest',
#  '1.17883673': 'the buildings are tall',
#  '1.17889622': 'autumn leaves float in a pond',
#  '1.17908671': 'the milky way and a few stars are visible in the night sky',
#  '1.17922739': 'a dog wearing a black and yellow hoodie',
#  '1.17937926': 'a large elephant standing in the desert',
#  '1.17943963': 'a close up of a tree with red leaves',
#  '1.17985381': 'a person holding a yellow leaf over the water',
#  '1.18039924': 'two pineapples sitting on the sand',
#  '1.18042670': 'three cooling towers with smoke coming out of them',
#  '1.18052517': 'two women walking through a field with a suitcase',
#  '1.18083771': 'two palm trees are standing tall against a blue sky',
#  '1.18199100': 'the moon is setting over the mountains in the desert',
#  '1.18245228': 'the milky way over a forest with trees and stars',
#  '1.18332632': 'a mountain range with a few peaks',
#  '1.18560540': 'a pagoda on top of a hill at sunset',
#  '1.18572833': 'wind farm in the middle of the ocean',
#  '1.18605709': 'a short - eared owl in flight over a field',
#  '1.18751157': 'the night sky over mountains with stars',
#  '1.18769609': 'the city of montreal at dusk',
#  '1.18784788': 'a view of the ocean and mountains from a boat',
#  '1.18790188': 'a cat is walking in the grass with leaves',
#  '1.18840521': 'an aerial view of a plane in the forest',
#  '1.18874690': 'close up of green grass with water droplets',
#  '1.18958212': 'king penguins on the beach in front of mountains',
#  '1.19040794': 'a person standing on a mountain top',
#  '1.19141692': 'an ice covered surface with leaves and dirt',
#  '1.19171803': 'a pink and white background with bubbles and bubbles',
#  '1.19350471': 'two old boats are sitting on the shore',
#  '1.19353381': 'a white dog standing on a rocky hill',
#  '1.19383795': 'an aerial view of a small town with houses',
#  '1.19425411': 'two white daisies are sitting in the grass',
#  '1.19442906': 'the aurora borealis is seen over the mountains in iceland',
#  '1.19468297': "a dog is being held in a person's jacket",
#  '1.19499404': 'yosemite valley sunset',
#  '1.19540815': 'a yellow rose is shown in front of a dark background',
#  '1.19544013': 'two baskets with sunflowers in them',
#  '1.19624200': 'man standing on a pier with red smoke',
#  '1.19644801': 'a lake surrounded by trees and mountains',
#  '1.19657102': 'a snowy mountain with trees and the sun setting',
#  '1.19699439': 'a person holding a handful of shells on the beach',
#  '1.19724092': 'a beach with palm trees and umbrellas',
#  '1.19732977': 'a lone person standing on a hill at sunset',
#  '1.19749642': 'a palm tree with leaves and a blue sky',
#  '1.19831869': 'a forest with trees and fog',
#  '1.19849350': 'a mountain is reflected in the water of a lake',
#  '1.19922049': 'a coral reef with many different types of corals',
#  '1.20045763': 'a lone person standing on top of a mountain',
#  '1.20087934': 'the flatiron building in new york city',
#  '1.20121163': 'a large mountain with a lake in the middle',
#  '1.20145206': 'a woman in a field of sunflowers',
#  '1.20162106': 'a sheep grazing in a field with a cloudy sky',
#  '1.20247336': 'a person standing on top of a mountain with snow capped peaks',
#  '1.20264120': 'a single pink peony in a mason jar on a table',
#  '1.20391899': 'a man walking on the beach near the ocean',
#  '1.20397367': 'a close up of a bunch of cactus plants',
#  '1.20481067': 'an aerial view of a rocky shoreline with a boat',
#  '1.20522382': 'a woman holding a bouquet of yellow flowers',
#  '1.20527967': 'a field of tall grass and trees in the fog',
#  '1.20549534': 'black and white photo of a pier with people on it',
#  '1.20565832': 'a person standing on top of a sand dune',
#  '1.20843441': 'a plane flying over a mountain range with a yellow sky',
#  '1.20891636': 'a mountain with snow and clouds in the background',
#  '1.20919097': 'a view of a mountain range with trees and fog',
#  '1.21254672': 'a group of horses on a hill',
#  '1.21256345': 'a single flower floating in a blue pool',
#  '1.21351223': 'an aerial view of a wave crashing into the ocean',
#  '1.21434534': 'a lake with a body of water and a hill in the background',
#  '1.21480862': 'a small island with a house on it',
#  '1.21690412': 'an aerial view of a winding road',
#  '1.21743322': 'a waterfall in the mountains',
#  '1.21775635': 'a river running through a snowy forest with rocks and trees',
#  '1.21822966': 'silhouette of couple kissing on beach at sunset',
#  '1.21826524': 'a field of tall grass',
#  '1.21827738': 'two rhinos laying down on the ground',
#  '1.21838702': 'a herd of elephants standing on a hill',
#  '1.21839416': 'three giraffes drinking water from a pond',
#  '1.21845693': 'a cat laying on a bed',
#  '1.21901368': 'aerial view of the beach and forest',
#  '1.21983582': 'a moose with large antlers laying in the grass',
#  '1.22108667': 'a beach with a large tree in the middle of it',
#  '1.22117098': 'an aerial view of a road in the middle of a forest',
#  '1.22158566': 'a lighthouse sits on the rocky shoreline',
#  '1.22239142': 'a flock of birds flying in the sky',
#  '1.22307362': 'an aerial view of a small boat in the ocean',
#  '1.22333773': 'a person standing on top of a mountain with their arms outstretched',
#  '1.22343857': 'a close up of a fish with black spots on its face',
#  '1.22393103': 'a baby duck standing in the grass',
#  '1.22439752': 'a pineapple and a pink flower are on a cutting board',
#  '1.22519722': 'a black and white fish on a coral reef',
#  '1.22668939': 'a field of tall grass with a sunset in the background',
#  '1.22740119': 'people walk on a walkway over a mountain',
#  '1.22747278': 'a white crosswalk with red and orange leaves on the ground',
#  '1.23059936': 'an aerial view of a car driving down a winding road',
#  '1.23064738': 'a black and white photo of a mountain road',
#  '1.23068116': 'a fox sitting in tall grass',
#  '1.23091747': 'the milky way over the arizona desert',
#  '1.23124284': 'an aerial view of a frozen lake',
#  '1.23154434': 'a field of dry grass with frost on it',
#  '1.23167915': 'a forest with trees and sun shining through',
#  '1.23181038': 'a person on a surfboard riding a wave',
#  '1.23223683': 'a green plant with a monstera leaf in a white pot',
#  '1.23232638': 'a person walking across a snowy field',
#  '1.23315774': 'a group of people standing on a beach',
#  '1.23403268': 'an aerial view of the ocean and rocks',
#  '1.23440924': 'a plane flying in the sky',
#  '1.23442340': 'a leaf laying on the grass with water droplets on it',
#  '1.23450954': 'joshua tree national park, california',
#  '1.23663604': 'a purple and white image of a tumor',
#  '1.23740103': 'a close up of a plant with green leaves',
#  '1.23762132': 'icebergs in the ocean with blue water',
#  '1.23999810': 'a group of horses eating grass on a beach',
#  '1.24138104': 'a couple in red dresses walking on the beach',
#  '1.24279660': 'a view of a palm tree with leaves',
#  '1.24349485': 'a zebra standing in a dry field',
#  '1.24374243': 'a large snow covered hill',
#  '1.24504298': 'a person holding a coconut in front of palm trees',
#  '1.24620688': 'a person on a surfboard in the ocean',
#  '1.24628555': 'snow covered red rocks in sedona, arizona',
#  '1.24702096': 'a pink flamingo float in the pool with people in the background',
#  '1.24800818': 'a tractor pulling a trailer full of hay',
#  '1.24904918': 'a view of the sun shining through the clouds',
#  '1.24970356': 'a stack of rocks sitting on top of a stream',
#  '1.24989251': 'a person is skiing down a snowy slope',
#  '1.25000169': 'a glacier in the arctic with snow and ice',
#  '1.25021375': 'a shell on the beach',
#  '1.25056127': 'a small bird is sitting on a branch',
#  '1.25189604': 'a cherry blossom tree with the sun setting in the background',
#  '1.25224938': 'a plane flying in the sky with dark clouds',
#  '1.25390388': 'a desert with sand dunes and blue sky',
#  '1.25515137': 'a view of a forested valley with a road in the middle',
#  '1.25522732': 'a single daisy is shown in the foreground',
#  '1.25540230': 'a white dog standing on a wooden deck',
#  '1.25571179': 'a rainbow beam shines through the clouds above a forest',
#  '1.25782856': 'a mountain range',
#  '1.25819196': 'a leaf on a green background',
#  '1.25854955': 'a lake with mist and trees at sunrise',
#  '1.25986438': 'a cow standing in a field with a metal bucket',
#  '1.26033008': 'a person standing on a mountain top',
#  '1.26044345': 'a lake with tall grass and trees',
#  '1.26060361': 'a gray wall with a green ivy growing over it',
#  '1.26071029': 'a black and white photo of a flower',
#  '1.26243095': 'a jellyfish floating in the ocean with bubbles',
#  '1.26365764': 'a body of water',
#  '1.26411747': 'a flower garden with colorful flowers and green plants',
#  '1.26471996': 'a dog laying on a bed with a blanket',
#  '1.26529635': 'an aerial view of the ocean and beach',
#  '1.26619926': 'the rock of uluru, uluru national park, australia',
#  '1.26677531': 'a woman and two dogs in a field at sunset',
#  '1.26875612': 'a sunset on the beach with a rock in the water',
#  '1.26904322': 'a white dog standing on a dock in front of the ocean',
#  '1.26980162': 'cactus plant in front of buildings',
#  '1.27078890': 'grass and ocean on a cloudy day',
#  '1.27113734': 'a 3d rendering of a virus',
#  '1.27117611': 'a sunset over a field with a cow',
#  '1.27322927': 'a bird standing in the water',
#  '1.27379785': 'a red sand dune with a white stripe',
#  '1.27406535': 'a person sitting on a beach with a surfboard',
#  '1.27460025': 'two black birds walking on the sand',
#  '1.27478529': 'a dead tree branch on the sand',
#  '1.27668031': 'the moon is seen in the sky with a red ring',
#  '1.27853476': 'a man standing in front of a waterfall',
#  '1.27929097': 'a large waterfall',
#  '1.27979284': 'a flock of birds flying over a rocky island',
#  '1.27987302': 'a person standing in the middle of a field',
#  '1.28008910': 'a mountain peak is seen under a starry sky',
#  '1.28037597': 'a black and white cat yawning',
#  '1.28037779': 'red and white flowers in a field',
#  '1.28069092': 'a red bug on a blue flower',
#  '1.28183287': 'a wave breaking on the ocean surface',
#  '1.28276460': 'two sea lions on the beach',
#  '1.28396152': 'a butterfly with black spots on its wings is sitting on a pink flower',
#  '1.28480114': 'a rock with plants growing on it',
#  '1.28605591': 'a sunset over mountains',
#  '1.28803212': 'an aerial view of a forest with trees in the fall',
#  '1.28858381': 'a forest with trees and grass',
#  '1.28919877': 'a view of a snowy mountain range from a mountain top',
#  '1.29284487': 'a snowy forest with trees and snow',
#  '1.29327959': 'a field with a tree in the middle of it',
#  '1.29333922': 'a sunset over the mountains',
#  '1.29587024': 'a black and white photo of a surfer on a beach',
#  '1.29630552': 'a person standing in front of a window with rain drops on it',
#  '1.29760852': 'a close up of a fly on a leaf',
#  '1.30054062': 'a plane flying over a forest with trees in the background',
#  '1.30131546': 'a colorful building on a cliff overlooking the ocean',
#  '1.30551743': 'a close up of a gray cat with orange eyes',
#  '1.30562525': 'a sunflower is shown against a black background',
#  '1.30650859': 'an aerial view of a beach with waves and sand',
#  '1.30664833': 'a beautiful sunset over the clouds with mountains in the background',
#  '1.30741000': 'black and white photo of mountains and clouds',
#  '1.30868435': 'a view of the sky from an airplane',
#  '1.30914241': 'a cat peeking out from a cardboard box',
#  '1.30939846': 'a view of the ocean from under a wave',
#  '1.31025531': 'california poppies, california, california poppies, calif',
#  '1.31363759': 'a blue sky with white clouds',
#  '1.31425381': 'a sandy beach with people on it',
#  '1.31514230': 'a red squirrel is standing in the grass',
#  '1.31592439': 'the beach and ocean in big sur, california',
#  '1.31626840': 'beautiful landscape of alpine lake in austria with mountains and trees',
#  '1.31682532': 'a blurry image of a window with a wet window',
#  '1.31687102': 'a black and white photo of a tall tower',
#  '1.32098165': 'a sunset with a crescent moon',
#  '1.32117528': 'a mountain with snow on it and a cloud',
#  '1.32200070': 'green potted plant on white shelf',
#  '1.32289033': 'a man standing on a road with a light shining up in the sky',
#  '1.32605486': 'a horse standing in the middle of a field',
#  '1.32645692': 'a cactus stands tall in the desert under a starry sky',
#  '1.32733805': 'a woman holding white peonies in her hands',
#  '1.33037581': 'a single daisy is standing in the middle of a field',
#  '1.33171330': 'a person walking on a rock',
#  '1.33202676': 'a man sitting on a chair in a room',
#  '1.33258078': 'the sky is blue',
#  '1.33267997': 'a couple of dogs tied to a leash on a sidewalk',
#  '1.33283708': 'mount hood at night with stars and moon',
#  '1.33324800': 'a bridge with a train on it',
#  '1.33437435': 'a cow is standing in a field at sunset',
#  '1.33583999': 'a dog wearing a blue harness on a snowy day',
#  '1.33722577': 'a view of the ocean and cliffs at sunset',
#  '1.33958863': 'a yellow flower laying on a brick sidewalk',
#  '1.34679665': 'a white table with a cup and a vase of pink flowers',
#  '1.34732076': 'a person holding a fern leaf in their hand',
#  '1.34941240': 'a cat is silhouetted against the lights of a city',
#  '1.34952676': 'a boat floating in the ocean with a mountain in the background',
#  '1.35001258': 'rainbow over the fjord in norway',
#  '1.35013950': 'a crescent moon is seen in the sky with birds flying by',
#  '1.35161235': 'a lone wolf is walking across a snowy field',
#  '1.35322960': 'a black dog sitting on a rock',
#  '1.35394873': 'a man riding a wave in the ocean',
#  '1.35550171': 'a canal with palm trees and water in infrared',
#  '1.35565754': 'a pier is in the middle of the ocean with waves crashing into it',
#  '1.35639306': 'a colorful town on the coast of italy',
#  '1.35798938': 'bees on a honeycomb with honeycomb frames',
#  '1.35877658': 'a black dog with a yellow leash standing in the snow',
#  '1.36120715': 'a close up of a lizard on the ground',
#  '1.36374290': 'an aerial view of a large crater with steam coming out',
#  '1.36499143': 'a dog wearing a bandana on top of a mountain',
#  '1.36563060': 'a forest with trees and fog in the background',
#  '1.36774988': 'a person on a surfboard riding a wave on a beach',
#  '1.36776191': 'a plane flying over a beach at sunset',
#  '1.36792650': 'a large cloud is seen in the sky',
#  '1.36806652': 'a group of boats floating in the water',
#  '1.36819545': 'a person is holding up a mirror in the grass',
#  '1.36906614': 'a view of the ocean and trees on a rocky cliff',
#  '1.36957405': 'a mountain peak with snow on it',
#  '1.37062194': 'a large rock in the ocean',
#  '1.37481608': 'a man walking on a foggy road in the middle of nowhere',
#  '1.37520153': 'an aerial view of the ocean with orange and green lines',
#  '1.37718545': 'a wall with plants growing on it',
#  '1.37847930': 'a silhouette of trees in the forest at sunset',
#  '1.37877374': 'a large open field with a sky filled with clouds',
#  '1.38031279': 'a man sitting on a bench near the water',
#  '1.38747715': 'black sand beach with snow and mountains in the background',
#  '1.38945693': 'a woman in a mermaid tail',
#  '1.39332716': 'a person standing on a cliff overlooking the ocean',
#  '1.39453141': 'a jeep driving through the sand dunes',
#  '1.39636702': 'a view of the sky and the ocean from an airplane',
#  '1.39780788': 'baskets filled with flowers on a shelf',
#  '1.39925463': 'a cat walking on a chair',
#  '1.40531199': 'the stars are shining brightly in the night sky',
#  '1.41241135': 'a single pink flower is standing in the grass',
#  '1.41643998': 'a person riding a bike on a trail in the woods',
#  '1.42073001': 'a long road under the night sky with a full moon',
#  '1.42607127': 'a person walking on a beach',
#  '1.42762459': 'a mountain with a valley and clouds in the background',
#  '1.42770779': 'a red fox sitting in the grass',
#  '1.43710075': 'a rock with birds sitting on it',
#  '1.43739577': 'a vase with flowers sitting on a table',
#  '1.43805858': 'a snowy mountain with evergreen trees and snow',
#  '1.43886193': 'peaches on a wooden tray',
#  '1.43913351': 'a man and a woman are working in a greenhouse',
#  '1.43915274': 'a bird flying over a waterfall',
#  '1.43975218': 'a chameleon is sitting on a branch',
#  '1.44409855': 'a mountain covered in fog with trees in the foreground',
#  '1.44446874': 'a barn and a shooting star in the night sky',
#  '1.44690941': 'a view of a snowy mountain from an airplane',
#  '1.45230645': 'a person skiing down a snowy slope',
#  '1.45498840': 'a group of fish swimming in the ocean',
#  '1.45791278': 'a bunch of roses are in a vase',
#  '1.46033413': 'people standing on top of a mountain with clouds in the background',
#  '1.46144199': 'a view of clouds from an airplane',
#  '1.46871023': 'a close up of a tree with white flowers',
#  '1.48535014': 'a small pink flower in a white pot',
#  '1.48633711': 'a view of the ocean with waves crashing on the rocks',
#  '1.48635862': 'a woman in yellow sweater standing on a path in the fog',
#  '1.49035496': 'a sunset over the ocean with a person flying a kite',
#  '1.49170797': 'a tree with white flowers against a blue sky',
#  '1.49633738': 'a statue of a buddha sitting on the ocean floor',
#  '1.49646208': 'a plant with a shadow on a white wall',
#  '1.50026192': 'a road through a forest with trees and grass',
#  '1.50087537': 'a woman holding a bouquet of eucalyptus and eucalyptus leaves',
#  '1.50592122': 'a man walking across the desert with footprints',
#  '1.50661153': 'a mountain range with trees and fog',
#  '1.51174001': 'the sun shines through the clouds in this photo',
#  '1.51937264': 'a man standing on a ladder next to a dam',
#  '1.52089810': 'a tall pine tree is seen against a cloudy sky',
#  '1.52104947': 'an aerial view of a lighthouse on the coast',
#  '1.53695702': 'a view of the ocean from above',
#  '1.54266600': 'a tree in a field',
#  '1.55282950': 'an aerial view of a forest with a road',
#  '1.56499837': 'a cat laying on a bed',
#  '1.56814451': 'a man windsurfing in the ocean',
#  '1.57744860': 'an airplane flying over the clouds',
#  '1.59152929': 'a boat is floating in the water',
#  '1.61191724': 'a group of mushrooms in the forest',
#  '1.61449162': 'people sitting around a campfire on the beach at sunset',
#  '1.63450929': 'a couple riding horses on a dirt road',
#  '1.65105441': 'a large mountain',
#  '1.65454409': 'a wooden pier with a small cabin in the middle of a lake',
#  '1.66597654': 'a branch with red berries against a white background',
#  '1.67505411': 'a koala bear with her baby in her arms',
#  '1.74826599': 'a walkway in a greenhouse with palm trees',
#  '1.75945185': 'a beach with palm trees and a swing on the sand',
#  '1.77810004': 'an aerial view of a forest with trees',
#  '1.80501703': 'a man is riding a wave on a surfboard',
#  '1.85310216': 'a beach with footprints in the sand',
#  '1.86090836': 'a woman walking along the beach under palm trees',
#  '1.86225306': 'a man standing on a bridge in the fog',
#  '1.89143480': 'a bird flying over a bridge in the fog',
#  '2.00000000': 'a man standing on a rock overlooking the ocean',
#  '2.00006644': 'a cabin on the shore of a lake with mountains in the background',
#  '2.00020690': 'an aerial view of a road in the woods',
#  '2.00084214': 'a snow covered mountain with trees in the fog',
#  '2.00099549': 'man standing on top of a mountain looking out over the valley',
#  '2.00105497': 'a white horse running through a field of tall grass',
#  '2.00111112': 'the city of frankfurt, germany, at night',
#  '2.00128554': 'a mountain range is covered with clouds',
#  '2.00138281': 'the night sky over the ocean and beach',
#  '2.00201322': 'the sky is blue',
#  '2.00241420': 'mountains with snow capped peaks and a blue sky',
#  '2.00247820': 'a manger with a blanket on it in a hay field',
#  '2.00543019': 'a small tree in front of a waterfall',
#  '2.00573788': 'a man standing in front of a cave at the beach',
#  '2.00609147': 'a man standing on top of a mountain',
#  '2.00816899': 'a dragonfly with yellow and black wings is perched on a branch',
#  '2.00847573': 'a view of a tropical garden with plants and trees',
#  '2.00875288': 'a forest with trees and red flowers in the background',
#  '2.00915486': 'a dog wearing a sweater laying on a bed',
#  '2.00917437': 'a mountain range',
#  '2.00921333': 'a bee sits on an orange flower',
#  '2.00927663': 'a group of people on a beach',
#  '2.00949443': 'a road sign and a tree in the night sky',
#  '2.00954233': 'black and white photo of waterfall in the mountains',
#  '2.00988741': 'two hands holding a heart shaped bouquet of flowers',
#  '2.00999154': 'two purple water lilies are in a pond',
#  '2.01023176': 'a bush of white flowers with green leaves',
#  '2.01037398': 'a sign on a sidewalk',
#  '2.01040602': 'a path in the woods with grass and leaves',
#  '2.01051428': 'a river flowing through a rocky river bed with mountains in the background',
#  '2.01071680': 'a black and white photo of water',
#  '2.01111706': 'a man with a backpack walking up a mountain',
#  '2.01144521': 'mountain landscape with foggy trees',
#  '2.01156961': 'a dry cracked earth surface with a few trees',
#  '2.01168237': 'a man standing in the middle of a lake with mountains in the background',
#  '2.01283393': 'a view of the canyon from the top of a tall rock',
#  '2.01375017': 'the sun is seen through a cloudy sky',
#  '2.01381806': 'the grand canyon is a popular destination for tourists',
#  '2.01403779': 'a person holding a tarantula in their hands',
#  '2.01443949': 'a bee is on a lavender plant with purple flowers',
#  '2.01501416': 'an aerial view of a waterfall in the mountains',
#  '2.01510266': 'a couple of boats floating in a lake',
#  '2.01535722': 'the aurora borealis is seen over the mountains in iceland',
#  '2.01600182': 'a person is skiing down a mountain',
#  '2.01631987': 'a close up of a wave crashing into the ocean',
#  '2.01661514': 'a dog sitting in the back of a red suv',
#  '2.01665134': 'a castle in the middle of a forest',
#  '2.01682725': 'a vase with a bunch of flowers sitting on a table',
#  '2.01722865': 'a lifeguard tower on the beach',
#  '2.01733399': 'a river in the desert',
#  '2.01775174': 'a tent is lit up in the middle of a lake',
#  '2.01783686': 'a leaf hanging from a tree in the snow',
#  '2.01862638': 'blue and purple flowers are shown in this photo',
#  '2.01890610': 'red and black balloons floating in the air',
#  '2.01902077': 'a close up of some dried flowers',
#  '2.01929432': 'a colorful fish with bright red and blue stripes',
#  '2.01969318': 'a view of a waterfall in the middle of a green forest',
#  '2.02008961': 'a lone cow grazing in a field with a mountain in the background',
#  '2.02051875': 'a person walking through a canyon with a light shining through',
#  '2.02112372': 'a cactus plant in a garden with blue walls',
#  '2.02138228': 'a fire is burning in a dark room',
#  '2.02175861': 'guinea pigs and pineapple on orange background',
#  '2.02257338': 'a dog is standing in the grass with a red leash',
#  '2.02267195': 'a black dog running through the woods in the fall',
#  '2.02299888': 'a mountain range',
#  '2.02365351': 'man doing yoga on top of rock formation in greece',
#  '2.02377723': 'a colorful sunset over a field with trees',
#  '2.02407869': 'a woman with red hair and sunglasses standing in front of palm trees',
#  '2.02433180': 'aerial view of people on a beach in the ocean',
#  '2.02464846': 'a diver is looking at an old wreck',
#  '2.02467412': 'a river flows through a snowy forest at night',
#  '2.02562697': 'a man on a beach playing soccer',
#  '2.02630372': 'a view of a snowy mountain range under a stormy sky',
#  '2.02649715': 'a woman is petting a pug dog',
#  '2.02671298': 'a river in the middle of a mountain',
#  '2.02685556': 'the aurora borealis is seen over a mountain range',
#  '2.02719698': 'a person is holding a small piece of paper over a tray of soil',
#  '2.02811829': 'a man and his dog in a field of bluebells',
#  '2.02862457': 'the view from the top of a mountain in the lake district',
#  '2.02875408': 'a snowy mountain with a pink sky',
#  '2.02921492': 'two penguins standing on the sand',
#  '2.02993761': 'a man walking in the desert at sunset',
#  '2.03040224': 'a view up into the sky of tall pine trees',
#  '2.03084519': 'two bowls of food sitting on a table',
#  '2.03131331': 'a single pink flower is shown in front of a blurred background',
#  '2.03160526': 'a tree with brown leaves hanging from it',
#  '2.03190416': 'black and white photograph of water rushing over rocks',
#  '2.03302606': 'a mountain with snow on top',
#  '2.03312591': 'a long exposure of star trails over the ocean',
#  '2.03393604': 'a dog sitting in the middle of a field with some orange flowers',
#  '2.03415514': 'a bonsai tree in a pot on a table',
#  '2.03435722': 'a close up of a tree with dark leaves',
#  '2.03437054': 'a campfire with flames and logs',
#  '2.03439313': 'a road in valley of fire, nevada',
#  '2.03495401': 'a night sky with stars and a mountain in the background',
#  '2.03591098': 'a view of a hillside with houses on it',
#  '2.03627060': 'a forest with trees and fog in the background',
#  '2.03666406': 'a palm tree in the foreground with the sun setting behind it',
#  '2.03834874': 'a forest with mossy trees and rocks',
#  '2.03864208': 'a full moon is seen in the dark sky',
#  '2.03880371': 'a pile of logs with a lot of different sizes',
#  '2.03900958': 'a woman in a field with a sunflower',
#  '2.03907837': 'a silhouette of a mountain with clouds in the sky',
#  '2.03912999': 'a person sitting on a bench in a forest',
#  '2.03917379': 'ice on the rocks at sunset',
#  '2.03940624': 'a woman sitting on a bench with a cell phone',
#  '2.03992484': 'an aerial view of the ocean and rocks',
#  '2.04014398': 'a building with a clock on it',
#  '2.04047768': 'a lone person standing on top of a sand dune',
#  '2.04056699': 'a woman with her hair blowing in the wind',
#  '2.04066623': 'a view of a valley and mountains from a mountain top',
#  '2.04118862': 'a person holding a small fir branch in their hand',
#  '2.04129267': 'a mountain range',
#  '2.04132233': 'black and white photo of mountains and water',
#  '2.04142438': 'a view of the mountains from above',
#  '2.04154641': 'a white goose standing in front of two other geese',
#  '2.04159019': 'a man is eating a piece of cake',
#  '2.04172133': 'a wooden walkway leading to the ocean',
#  '2.04173697': 'a group of seals on the beach',
#  '2.04202715': 'an orange cat is sleeping on a window sill',
#  '2.04211230': 'a large mountain with a few sheep',
#  '2.04243366': 'a single pink rose is shown in front of a blurred background',
#  '2.04296293': 'a snowy mountain with a large snow covered mountain',
#  '2.04300666': 'a green grass texture background',
#  '2.04358725': 'a view of mountains and water in the snow',
#  '2.04385426': 'an abstract image of the sun setting over the ocean',
#  '2.04395595': 'a snowy mountain range with a few trees',
#  '2.04401014': 'a herd of reindeer in the snow',
#  '2.04402873': 'the water is choppy',
#  '2.04499281': 'man standing on top of mountain in the mountains',
#  '2.04513753': 'an iguana sitting on a rock in front of the ocean',
#  '2.04555852': 'an aerial view of a farm field with a house in the middle',
#  '2.04559113': 'a close up of grass in the snow',
#  '2.04628448': 'a full moon is seen over a forest with trees',
#  '2.04631354': 'amethyst crystal on white background',
#  '2.04641958': 'three bottles of perfume sitting next to a camera',
#  '2.04678314': 'a dog standing in the dark with a light shining on it',
#  '2.04710124': 'a person with a backpack on a mountain',
#  '2.04722087': 'a black and white photo of a city with a river',
#  '2.04852150': 'a large building with a large stone building in the background',
#  '2.04873866': 'a person standing on a mountain top with their arms outstretched',
#  '2.04956995': 'a close up of a plant with a flower',
#  '2.04980067': 'a polar bear swimming in a tank',
#  '2.05035855': 'a branch with some small red flowers hanging from it',
#  '2.05065746': 'a person wearing a red jacket',
#  '2.05147054': 'an aerial view of the ocean and hills',
#  '2.05156080': 'a mountain with snow and a sky full of stars',
#  '2.05172887': 'aerial view of car driving through autumn trees',
#  '2.05179662': 'a palm tree with leaves and a blue sky',
#  '2.05244712': 'a person on a surfboard is riding the waves',
#  '2.05288538': 'a large rock formation',
#  '2.05290627': 'a view of a mountain top with trees and a road',
#  '2.05315543': 'a cloudy sky',
#  '2.05359119': 'a man riding a horse in the desert',
#  '2.05381580': 'a black and white dog standing in the snow',
#  '2.05404797': 'a close up of a plant with purple flowers',
#  '2.05436783': 'sunset over the mountains',
#  '2.05502841': 'a man pouring a drink into a glass',
#  '2.05576721': 'autumn foliage in the white mountains, new hampshire, usa',
#  '2.05612172': 'a wave crashing on the beach at sunset',
#  '2.05698916': 'two children standing on a wooden bench',
#  '2.05782522': 'a dark sky with stars and a few lights',
#  '2.05797698': 'a rocky cliff with a small body of water',
#  '2.05838836': 'a cuttlefish with its mouth open in the dark',
#  '2.05899139': 'a lion laying on the ground',
#  '2.05956247': 'colorful autumn foliage on the trail',
#  '2.05983435': 'a boat on the ground',
#  '2.05983908': 'an aerial view of a large pile of ice',
#  '2.06006731': 'a black dog laying on a couch',
#  '2.06008590': 'a dirt road in the middle of a forest',
#  '2.06046198': 'a beach with a roller coaster and a water slide',
#  '2.06086223': 'a bonfire is lit on the ground near a lake',
#  '2.06087969': 'a view of central park from the top of a building',
#  '2.06100801': 'a starry night sky with a few stars',
#  '2.06171314': 'koi fish in the pond',
#  '2.06198018': 'an aerial view of the beach and ocean in bali, indonesia',
#  '2.06232257': 'a view of the sun through clouds',
#  '2.06234064': 'a sunset over the salt flats at the beach',
#  '2.06247039': 'a stream runs through a grassy field with mountains in the background',
#  '2.06294754': 'people walking through a cave on a beach',
#  '2.06332015': 'a tropical garden with lots of plants and trees',
#  '2.06343199': 'a blue sky with a blue sky background',
#  '2.06345388': 'a beach with a large body of water',
#  '2.06365835': 'a bowl of peaches and an open book on a table',
#  '2.06412101': 'a view of the ocean from an airplane',
#  '2.06446041': 'a person standing on a rocky mountain',
#  '2.06491826': 'a blue plastic bag hanging from a tree',
#  '2.06496221': 'a dirt road with a tree in the background',
#  '2.06549195': 'a grey seal on a rock',
#  '2.06593301': 'coffee beans heart shape on wooden table',
#  '2.06686508': 'zakynthos island, greece',
#  '2.06689896': 'a pair of hiking boots and a hat on the ground',
#  '2.06704247': 'a path through a tropical jungle with lots of plants',
#  '2.06710334': 'a view of the ocean at sunset',
#  '2.06722760': 'a close up of a stone floor with many different colors',
#  '2.06762777': 'a wet bench',
#  '2.06817529': 'a sunset over a lake',
#  '2.06825083': 'a man standing on a mountain top with a backpack',
#  '2.06825338': 'a person standing on the side of a road looking at the sky',
#  '2.06839603': 'a turtle with yellow and black markings',
#  '2.06888207': 'the sun is rising over the clouds in this photo',
#  '2.06922380': 'plitvice lakes national park, croatia',
#  '2.06941765': 'a sunset over a power line',
#  '2.07001310': 'a boat in the ocean with mountains in the background',
#  '2.07080886': 'monument valley sunset',
#  '2.07117609': 'a group of flamingos standing in the water',
#  '2.07144492': 'two puppies in a basket on the grass',
#  '2.07222886': 'a black and white dog wearing a red collar',
#  '2.07241629': 'two sheep standing on a hill',
#  '2.07308492': 'sunlight shining through leaves of an olive tree',
#  '2.07392804': 'a sunset over the ocean with clouds',
#  '2.07485424': 'rose petals on white background',
#  '2.07491465': 'a bird flying over the water with its wings spread',
#  '2.07522284': 'a blue and white marble surface with bubbles',
#  '2.07645364': 'a path on a hillside with grass and trees',
#  '2.07722935': 'a woman in a red and black scarf sitting in tall grass',
#  '2.07729906': 'a view of the ocean from a cliff',
#  '2.07753752': 'a jellyfish floating in the ocean with its tentacles out',
#  '2.07779232': 'a dark cloud is seen in the sky',
#  '2.07783173': 'a butterfly with orange and black stripes on its wings',
#  '2.07809986': 'the virgin river in zion national park',
#  '2.07812808': 'a bird feeder hanging from a tree in a park',
#  '2.07821699': 'a black and white photo of a cave with water flowing out',
#  '2.07852011': 'a close up of red berries on a branch',
#  '2.07872574': 'a woman holding a sign that says earth',
#  '2.07908402': 'a forest with trees and smoke coming from it',
#  '2.07914774': 'the sky is filled with stars and the trees are bare',
#  '2.07947229': 'a mountain with red and black lava flowing down it',
#  '2.07997154': 'waterfall in the jungle',
#  '2.08011700': 'a waterfall in the forest with green trees',
#  '2.08024660': 'a small town with houses and a church',
#  '2.08066741': 'a close up of white flowers in a garden',
#  '2.08074429': 'an orange cat is hiding in the bushes',
#  '2.08078801': 'lightning strikes over a city street at night',
#  '2.08084842': 'a view of a cloudy sky with some dark clouds',
#  '2.08099293': 'an aerial view of a wave breaking on the ocean',
#  '2.08114404': 'a dark stormy sky',
#  '2.08210090': 'aerial view of tropical beach with palm trees',
#  '2.08225556': 'a desk with a window and blinds in a room',
#  '2.08248486': 'a large elephant with tusks',
#  '2.08256170': 'an aerial view of a building with many balconies',
#  ...}

# %%
import json 
with open('datasets/scale1_2/unplash2000_blip2.json', 'w') as f:
    json.dump(texts, f, indent=4)
